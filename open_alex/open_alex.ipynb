# %%
import os
import json
import pandas as pd

# %% [markdown]
# #### Open Alex

# %%
from literature_search import search_openalex_papers

# %%
papers, keywords = search_openalex_papers("MCF7 Breast Cancer", max_results=10)
print(f"Keywords used: {keywords}")
print(f"Number of papers: {len(papers)}")
for j in range(len(papers)):
    print(f"Paper {j+1} format:")
    for key, value in papers[j].items():
        print(f"  {key}: {value}")
# Out:
# [SEARCH_OPENALEX] DEBUG: Processing keyword 1/1: 'MCF7 Breast Cancer'
# [OpenAlex] Retrieved 10 papers for keywords: 'MCF7 Breast Cancer'
# [SEARCH_OPENALEX] SUCCESS: Found 10 papers for keyword: 'MCF7 Breast Cancer'
# [SEARCH_OPENALEX] SUMMARY: 1/1 queries successful, 10 unique papers found
# Keywords used: ['MCF7 Breast Cancer']
# Number of papers: 10
# Paper 1 format:
#   semantic_scholar_id: https://openalex.org/W2099284837
#   type: openalex_abstract
#   year: 2006
#   authors: [{'authorId': 'https://openalex.org/A5026062254', 'name': 'Marie‐Noëlle Dieudonné'}, {'authorId': 'https://openalex.org/A5012012071', 'name': 'Marianne Bussière'}, {'authorId': 'https://openalex.org/A5025861339', 'name': 'Esther Dos Santos'}, {'authorId': 'https://openalex.org/A5090580749', 'name': 'Marie-Christine Leneveu'}, {'authorId': 'https://openalex.org/A5054290642', 'name': 'Yves Giudicelli'}, {'authorId': 'https://openalex.org/A5110037331', 'name': 'René Pecquery'}]
# ...
