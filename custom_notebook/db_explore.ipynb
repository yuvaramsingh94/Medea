# %%
import os
import ast
import pandas as pd
import torch
import numpy as np

# %% [markdown]
# #### pinnacle embeds

# %%
from pathlib import Path
DB_PATH = str(Path.cwd() / ".."/ "database" / "MedeaDB")
PIN_PATH = os.path.join(DB_PATH, "pinnacle_embeds")

# %%
file_path = os.path.join(PIN_PATH, "pinnacle_labels_dict.txt")
if os.path.exists(file_path):
    with open(file_path, "r") as f:
        dict_str = f.read()
        labels_dict = ast.literal_eval(dict_str)
    print(type(labels_dict))
    #print(labels_dict)
else:
    print(f"File not found: {file_path}")
# Out:
# <class 'dict'>

# %%
labels_dict.keys()
# Out:
# dict_keys(['Cell Type', 'Name', 'Degree', 'Relative Degree', 'Overlap'])

# %%
name_list = labels_dict["Name"]
print(len(name_list), len(set(name_list)))
# Out:
# 395134 14017

# %%
cell_list = labels_dict["Cell Type"]
print(len(cell_list), len(set(cell_list)))
# Out:
# 395134 530

# %%
len(labels_dict["Degree"])
# Out:
# 395134

# %%
name_list[-10:]
# Out:
# ['Sanity Check mature nk t cell',
#  'Sanity Check mesenchymal stem cell',
#  'Sanity Check retinal blood vessel endothelial cell',
#  'Sanity Check mature enterocyte',
#  'Sanity Check macrophage',
#  'Sanity Check artery endothelial cell',
#  'Sanity Check pancreatic acinar cell',
#  'Sanity Check connective tissue cell',
#  'Sanity Check b cell',
#  'Sanity Check cd24 neutrophil']

# %%
cell_list[-10:]
# Out:
# ['Sanity Check mature nk t cell',
#  'Sanity Check mesenchymal stem cell',
#  'Sanity Check retinal blood vessel endothelial cell',
#  'Sanity Check mature enterocyte',
#  'Sanity Check macrophage',
#  'Sanity Check artery endothelial cell',
#  'Sanity Check pancreatic acinar cell',
#  'Sanity Check connective tissue cell',
#  'Sanity Check b cell',
#  'Sanity Check cd24 neutrophil']

# %%
labels_dict["Degree"]
# Out:
# [100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
# ...

# %%
len(labels_dict["Overlap"])
# Out:
# 395134

# %%
cell_typ_list = labels_dict["Cell Type"]
print(len(cell_typ_list))
# Out:
# 395134

# %%
pin_protein_embed = torch.load(os.path.join(PIN_PATH, "pinnacle_protein_embed.pth"))
# Out:
# C:\Users\harip\AppData\Local\Temp\ipykernel_23012\275190232.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
print(pin_protein_embed.keys())
# Out:
# dict_keys([47, 51, 127, 13, 28, 105, 77, 129, 53, 99, 119, 100, 27, 46, 11, 153, 138, 17, 8, 35, 114, 22, 19, 42, 85, 37, 128, 36, 60, 0, 151, 126, 110, 116, 38, 52, 50, 104, 15, 23, 149, 143, 144, 103, 125, 76, 146, 70, 94, 150, 6, 95, 106, 43, 133, 20, 59, 121, 54, 80, 117, 55, 72, 145, 122, 48, 12, 41, 3, 111, 141, 49, 140, 101, 32, 66, 34, 78, 2, 14, 44, 45, 64, 102, 123, 74, 71, 130, 124, 148, 26, 18, 154, 21, 152, 90, 97, 82, 57, 139, 63, 58, 109, 24, 134, 40, 113, 108, 84, 9, 10, 56, 75, 155, 98, 131, 136, 39, 96, 115, 81, 30, 79, 73, 65, 92, 7, 83, 67, 68, 69, 142, 118, 33, 61, 87, 107, 137, 1, 91, 135, 31, 25, 120, 147, 62, 89, 93, 132, 88, 86, 4, 112, 29, 5, 16])

# %%
len(pin_protein_embed.keys())
# Out:
# 156

# %%
pin_protein_mg_embed = torch.load(os.path.join(PIN_PATH, "pinnacle_mg_embed.pth"))
print(pin_protein_mg_embed.shape)
# Out:
# torch.Size([218, 128])
# C:\Users\harip\AppData\Local\Temp\ipykernel_23012\670322817.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
pin_protein_embed[51].shape
# Out:
# torch.Size([1297, 128])

# %%
ppi_embed_dict = torch.load(os.path.join(PIN_PATH, "ppi_embed_dict.pth"))
# print(ppi_embed_dict.shape)
# Out:
# C:\Users\harip\AppData\Local\Temp\ipykernel_23012\1926914728.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
ppi_embed_dict.keys()
# Out:
# dict_keys(['acinar_cell_of_salivary_gland', 'adipocyte', 'adventitial_cell', 'alveolar_fibroblast', 'artery_endothelial_cell', 'b_cell', 'basal_cell', 'basal_cell_of_prostate_epithelium', 'bladder_urothelial_cell', 'bronchial_smooth_muscle_cell', 'bronchial_vessel_endothelial_cell', 'capillary_endothelial_cell', 'cardiac_endothelial_cell', 'cardiac_muscle_cell', 'cd141-positive_myeloid_dendritic_cell', 'cd1c-positive_myeloid_dendritic_cell', 'cd24_neutrophil', 'cd4-positive_helper_t_cell', 'cd4-positive,_alpha-beta_memory_t_cell', 'cd8-positive,_alpha-beta_cytokine_secreting_effector_t_cell', 'cd8-positive,_alpha-beta_cytotoxic_t_cell', 'cell_of_skeletal_muscle', 'ciliary_body', 'ciliated_cell', 'ciliated_epithelial_cell', 'classical_monocyte', 'club_cell', 'club_cell_of_prostate_epithelium', 'conjunctival_epithelial_cell', 'connective_tissue_cell', 'corneal_epithelial_cell', 'corneal_keratocyte', 'dendritic_cell', 'dn1_thymic_pro-t_cell', 'dn3_thymocyte', 'dn4_thymocyte', 'double-po
# ...

# %%
vein_endothelial_cell = ppi_embed_dict["vein_endothelial_cell"].keys()
print(vein_endothelial_cell)
# Out:
# dict_keys(['NCOA7', 'FSTL1', 'RAB14', 'RPL24', 'YAP1', 'PSMD13', 'ATG4A', 'CALM1', 'SDAD1', 'ERH', 'DOLK', 'FOS', 'FDPS', 'SRM', 'PARVB', 'ZPR1', 'LMO2', 'HSD17B12', 'WTIP', 'MRPL15', 'FXR1', 'COPS5', 'ZC3H15', 'STAU2', 'BLMH', 'EEF2K', 'SPAG9', 'GOLGA7', 'GAR1', 'RAB35', 'SHISA5', 'EIF3D', 'OXA1L', 'HLA-A', 'SNRNP40', 'LOXL2', 'GNB4', 'ZFAND5', 'ROCK2', 'YBX3', 'MAP3K11', 'RPL17', 'MPG', 'CCT4', 'RACK1', 'CANT1', 'RAMP3', 'SDF2', 'EGR3', 'STRN3', 'MRPL50', 'PPP3CC', 'BAG3', 'PIP4K2B', 'PNPLA2', 'MAST4', 'GALK1', 'CHCHD2', 'CD274', 'ZMIZ1', 'RP9P', 'BIRC2', 'PHAX', 'AP3M2', 'PRKAA1', 'HMGXB4', 'FERMT2', 'MIER2', 'PCF11', 'IPO7', 'MKNK2', 'DDX58', 'MTDH', 'DYNC1I2', 'USP4', 'CEBPG', 'LAYN', 'GSK3B', 'SIK1B', 'FUS', 'SNAP29', 'LIMS2', 'KLC1', 'GDI2', 'CLASP1', 'CAVIN1', 'SLC24A1', 'CSPP1', 'BMP1', 'CDC42', 'HPCAL1', 'INTS3', 'UTP6', 'TAF11', 'TIMP1', 'RNF7', 'UBE2L3', 'AP2S1', 'PNO1', 'DSP', 'SNW1', 'NANS', 'NACC2', 'BAHD1', 'NAV3', 'FLNA', 'BUD31', 'KALRN', 'ZNF34', 'CFH', 'SLC39A10',
# ...

# %%
acinar_cell_of_salivary_gland = ppi_embed_dict["acinar_cell_of_salivary_gland"].keys()
print(acinar_cell_of_salivary_gland)
# Out:
# dict_keys(['SSR2', 'YAP1', 'ERG28', 'CMTM4', 'DOLK', 'FOS', 'ADGRL2', 'SRM', 'FDPS', 'ARHGEF5', 'UQCC2', 'NUDT22', 'SLC37A4', 'QDPR', 'FXYD3', 'TENT5A', 'RAB27B', 'EEF2K', 'TRAF3IP1', 'GFPT1', 'POF1B', 'ROCK2', 'USP54', 'YBX3', 'MPG', 'CRB3', 'HLTF', 'CANT1', 'WIPI1', 'ACO2', 'TP53BP1', 'ABHD11', 'MAST4', 'MCEE', 'FAN1', 'WDR24', 'COMTD1', 'ATOX1', 'CERS4', 'NDUFA1', 'FERMT2', 'NDFIP2', 'PIGP', 'DROSHA', 'FAM241B', 'MOK', 'GSK3B', 'CLDND2', 'PAK3', 'YAE1', 'HIPK2', 'CST2', 'SYTL4', 'PCCB', 'ALG8', 'SLC4A2', 'DSP', 'MORN2', 'BTRC', 'DMTN', 'SYNE4', 'DAGLA', 'PPM1A', 'PIK3R1', 'TGFA', 'CDK16', 'LONP2', 'STX8', 'CDCA7L', 'ZFHX3', 'RINT1', 'CXXC4', 'WBP1L', 'KIF3B', 'DUSP10', 'ALDH3B2', 'PON2', 'TEF', 'ARFIP2', 'TSC1', 'CLDN4', 'RHBDF1', 'COPB1', 'MAP3K21', 'ETFDH', 'LAS1L', 'SLC9A7', 'ACTR3B', 'MTERF2', 'BTBD3', 'COBLL1', 'NOP53', 'NPC1', 'METAP2', 'ZNF33B', 'IGHA1', 'CST6', 'ACVR1B', 'CITED4', 'SLC11A2', 'ERCC1', 'TEC', 'EPHB3', 'EDN3', 'CBY1', 'GOLGB1', 'STAP2', 'ATP5MC1', 'LIG3', 'CA
# ...

# %%
acinar_cell_of_salivary_gland = ppi_embed_dict["adipocyte"].keys()
print(acinar_cell_of_salivary_gland)
# Out:
# dict_keys(['RAB14', 'RPL24', 'YAP1', 'PSMD13', 'CMTM4', 'ERG28', 'POLR1D', 'DCTN5', 'SDAD1', 'ERH', 'ANKZF1', 'FDPS', 'ARHGEF5', 'CYFIP2', 'UQCC2', 'HSD17B12', 'MRPL15', 'FXR1', 'NUDT22', 'QDPR', 'ZC3H15', 'FXYD3', 'WDR61', 'PSMD7', 'BLMH', 'ZNF318', 'RAB27B', 'GOLGA7', 'PDE12', 'PAPOLA', 'GAR1', 'SHISA5', 'EIF3D', 'OXA1L', 'SNRNP40', 'RPL17', 'RACK1', 'ETF1', 'TRIP6', 'YARS2', 'ACO2', 'POLR3A', 'PER3', 'ZFC3H1', 'MRPL50', 'TP53BP1', 'PNPLA2', 'MAST4', 'FOXJ3', 'CHCHD2', 'MCEE', 'ZMIZ1', 'FAM126B', 'FAN1', 'ELP2', 'COMTD1', 'PHAX', 'ATOX1', 'CERS4', 'NDUFA1', 'ZC3H8', 'IPO7', 'NDFIP2', 'MKNK2', 'MSH2', 'SHPRH', 'MTDH', 'DYNC1I2', 'USP4', 'MOK', 'PPP2CA', 'ACAD8', 'GSK3B', 'ATP5F1E', 'SNAP29', 'KLC1', 'GDI2', 'CAVIN1', 'NUDT12', 'AKT2', 'ZXDC', 'NUDCD2', 'DGKA', 'HIPK2', 'DHTKD1', 'RNF7', 'PCCB', 'PLIN3', 'GTF2A1', 'AP2S1', 'DSP', 'MORN2', 'SERTAD4', 'BTRC', 'PPM1A', 'SNW1', 'PIK3R1', 'TFB2M', 'MAPRE1', 'RSRC2', 'SLC52A2', 'COX15', 'LONP2', 'BUD31', 'SLC7A5', 'SIGMAR1', 'MBD2', 'BLOC1
# ...

# %% [markdown]
# #### depmap

# %%
from pathlib import Path
DB_PATH = str(Path.cwd() / ".."/ "database" / "MedeaDB")
DEP_PATH = os.path.join(DB_PATH, "depmap_24q2")

# %%
file_path = os.path.join(DEP_PATH, "gene_names.txt")
if os.path.exists(file_path):
    with open(file_path, "r") as f:
        gene_names = [line.strip() for line in f.readlines()]
    print(type(gene_names))
    print(f"Number of genes: {len(gene_names)}")
else:
    print(f"File not found: {file_path}")
# Out:
# <class 'list'>
# Number of genes: 18443

# %%
gene_names
# Out:
# ['A1BG',
#  'A1CF',
#  'A2M',
#  'A2ML1',
#  'A3GALT2',
#  'A4GALT',
#  'A4GNT',
#  'AAAS',
#  'AACS',
#  'AADAC',
#  'AADACL2',
#  'AADACL3',
#  'AADACL4',
#  'AADAT',
#  'AAGAB',
#  'AAK1',
#  'AAMDC',
#  'AAMP',
#  'AANAT',
#  'AAR2',
#  'AARD',
#  'AARS1',
#  'AARS2',
#  'AARSD1',
#  'AASDH',
#  'AASDHPPT',
#  'AASS',
#  'AATF',
#  'AATK',
#  'ABAT',
#  'ABCA1',
#  'ABCA10',
#  'ABCA12',
#  'ABCA13',
#  'ABCA2',
#  'ABCA3',
#  'ABCA4',
#  'ABCA5',
#  'ABCA6',
#  'ABCA7',
#  'ABCA8',
#  'ABCA9',
#  'ABCB1',
#  'ABCB10',
#  'ABCB11',
#  'ABCB4',
#  'ABCB5',
#  'ABCB6',
#  'ABCB7',
#  'ABCB8',
#  'ABCB9',
#  'ABCC1',
#  'ABCC10',
#  'ABCC11',
#  'ABCC12',
#  'ABCC2',
#  'ABCC3',
#  'ABCC4',
#  'ABCC5',
#  'ABCC6',
#  'ABCC8',
#  'ABCC9',
#  'ABCD1',
#  'ABCD2',
#  'ABCD3',
#  'ABCD4',
#  'ABCE1',
#  'ABCF1',
#  'ABCF3',
#  'ABCG1',
#  'ABCG2',
#  'ABCG4',
#  'ABCG5',
#  'ABCG8',
#  'ABHD1',
#  'ABHD10',
#  'ABHD11',
#  'ABHD12',
#  'ABHD12B',
#  'ABHD13',
#  'ABHD14A',
# ...

# %%
gene_idx_array = np.load(os.path.join(DEP_PATH, "gene_idx_array.npy"))

# %%
gene_idx_array
# Out:
# array(['A1BG', 'A1CF', 'A2M', ..., 'ZYX', 'ZZEF1', 'ZZZ3'], dtype='<U12')

# %%
corr_matrix = np.load(os.path.join(DEP_PATH, "corr_matrix.npy"))
corr_matrix.shape
# Out:
# (18443, 18443)

# %%
p_adj_matrix = np.load(os.path.join(DEP_PATH, "p_adj_matrix.npy"))
p_adj_matrix.shape
# Out:
# (18443, 18443)

# %%
p_val_matrix = np.load(os.path.join(DEP_PATH, "p_val_matrix.npy"))
p_val_matrix.shape
# Out:
# (18443, 18443)
